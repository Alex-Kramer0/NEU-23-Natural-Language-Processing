# %% [markdown]
# Homework 2: LLMs Experiments & Hyperparameters, LLMs Philosophy
# ----
#
# Due date: September 20th, 2023
#
# Points: 60
#
# Goals:
# - explore and understand some of the hyperparameters available to you with LLMs
# - consider more deeply the philosophy of AI and LLMs
#
#
# Complete in groups of: __one (individually)__
#
# Allowed python modules:
# - You are not to use a library's implementation of `softmax`. You may use the `random` and `numpy` libraries in this assignment.
#
# Instructions:
# - Complete outlined problems in this notebook.
# - When you have finished, __clear the kernel__ and __run__ your notebook "fresh" from top to bottom. Ensure that there are __no errors__.
#     - If a problem asks for you to write code that does result in an error (as in, the answer to the problem is an error), leave the code in your notebook but commented out so that running from top to bottom does not result in any errors.
# - Double check that you have completed Task 0.
# - Submit your work on Gradescope.
# - Double check that your submission on Gradescope looks like you believe it should __and__ that all partners are included (for partner work).
#
# 6120 students: complete __all__ problems.
#
# 4120 students: you are not required to complete problems marked "CS 6120 REQUIRED". If you complete these you will not get extra credit. We will not take points off if you attempt these problems and do not succeed.

# %% [markdown]
# Task 0: Name, References, Reflection (5 points)
# ---
#
# TODO: complete this section
#
# Name: Alex Kramer - ALIGN Data Science
#
# References
# ---
# List the resources you consulted to complete this homework here. Write one sentence per resource about what it provided to you. If you consulted no references to complete your assignment, write a brief sentence stating that this is the case and why it was the case for you.
#
#
# - https://docs.cohere.com/docs/temperature
#     - Read about temperature to better understand how to code it.
# - https://docs.cohere.com/docs/controlling-generation-with-top-k-top-p
#     - Read about top-k to better understand how to code it.
# - https://www.freecodecamp.org/news/how-to-square-a-number-in-python-squaring-function/
#     - Read about how to square a number in python, I forgot the syntax.
# - https://towardsdatascience.com/how-to-sample-from-language-models-682bceb97277
#     - Read about top-k sampling and how it works.
# - Office Hours
#     - Went to office hours to learn more about the math notation in Task 2. Worked with TA's on fixing problems in code.
#
#
# AI Collaboration
# ---
# Following the *AI Collaboration Policy* in the syllabus, please cite any LLMs that you used here and briefly describe what you used them for. Additionally, provide comments in-line identifying the specific sections that you used LLMs on, if you used them towards the generation of any of your answers.
#
#
# Reflection
# ----
# Answer the following questions __after__ you complete this assignment (no more than 1 sentence per question required, this section is graded on completion):
#
# 1. Does this work reflect your best effort?
# Somewhat, I spent a lot of time and energy on this assignment, but I also had a quiz for my other class this week which made things harder to juggle.
#
# 2. What was/were the most challenging part(s) of the assignment?
# It was hard to get the website AI goose to work with me on creating a story. I also struggled with understanding the math notation in Task 2, but I think that is just beause of my lack of math background.
#
# 3. If you want feedback, what function(s) or problem(s) would you like feedback on and why?
# I really enjoyed this assignment, but having some more resources to explain what certains things are would be helpful. Such as a definition for k-top or temperature and how that works.

# %% [markdown]
# Task 1: Large Language Models Experiments (20 points)
# ---
#
# Sign up for an account at [goose.ai](https://goose.ai), then navigate to the AI Playground. You can use any of the GPT-X models for this task. Your goal is to get the models that you play with to tell a coherent story where you are the main character. Once you have the story that allows you to answer the questions below, copy and paste it into your document. Note that you may not be "successful" in your goal to have the model tell a truly coherent story—that's okay.
#
# You'll be playing with various hyperparameters with these experiments. A hyperparameter is a parameter of a model that is manually set and controls some aspect of either the learning algorithm or the output algorithm.

# %% [markdown]
# __Let's write a story together in which I, Alex, am the main character.__
# I want there to also be another character, Jane Doe, so my story is the following: I see Alex and Doe on an adventure on top of high rocks at dawn when there was a storm and all of their faces are covered and blazing with red fire. __They barely made it to the top of the rocks__ safely as if by pure luck because Alex pushed Jane and both of then held the rocks tightly, the wind, storm & red clouds flying in their own direction to try and break the magic. __It all started last week when__ Jane Doe was icing her car. Suddenly from nowhere in a cloud in her garage, A lightning bolt, which looked like Jane Doe (Alex's first name) shot from the middle and the lightning bolt hit Jane while her hair is covered and both Jane and lightning disappeared as did her and both Alex was alone and confused... And a red flame began spreading all around. __After Jane disappeared from the garage,__ <mark>yellow Alex was still confused and said "Did you see that?"</mark> <span style="background-color:red">Next he sprung up and ran to the edge of the rock and looked down.</span> __He saw__ _the storm and lightning and he saw Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm and lightning and Jane and the storm_
#
# __He saw__ _the storm and lightning and he saw the red fire. He was so confused because he saw Jane and then he saw the storm and lightning and he saw the red fire. He was so confused that he ran into the house and started to cry._

# %% [markdown]
# 1. Highlight in <mark>yellow</mark> demonstrations of changing the temperature hyperparameter. To do this in markdown, `<mark>yellow highlighted text here</mark>`.
# 2. Highlight in <span style="background-color:red">red</span> demonstrations of changing the top-k hyperparameter. To do this in markdown, `<span style="background-color:red">red text here</span>`.
# 3. Indicate a demonstration of the probabilistic nature of the output of LLMs by *italicizing* at least two spans of text demonstrating identifiable probabilistic output.
#
# If background colors are not rendering in your IDE, you may alternatively use 🔥 emojis around temperature and 🔴s around top-k.

# %% [markdown]
# Task 2: Create Hyperparameter Demonstrations (15 points)
# ----
#
# (python) Create a demonstration in a jupyter notebook of changing a temperature hyperparameter. To do this, follow the steps below:
# choose an "input sequence" of 2 - 5 words to ground your example.
# 1. define a vocabulary of size >= 10
# 2. for each item in the vocabulary, choose a float, $z_i$ in the range of [-1, 1] . Generally speaking, you'll want words with higher probabilities to have a number closer to 1, words with lower probabilities to have a number closer to -1.
# 3. implement a `softmax` function (equation written below), calculate and display your starting probability distribution ezij = 1ezj where $e$ is the math value $e$ (`math.e`), $z_i$ is the value you chose in step 2 for the target word, and $j$ goes through all words in your vocabulary (this is the sum of $e$ raised to the power of all your $z$ values). You should end up with a well-formed probability distribution. This probability distribution should reflect reasonable probabilities for your vocabulary given your input sequence.
# $$ \texttt{softmax}(z_i) = \frac{e^{z_i}}{\sum_{j = 1}^k e^{z_j}}$$
# 4. Add a temperature parameter ($\tau$) to your softmax function (equation below) and demonstrate the results of raising and lowering the temperature. For your demonstration, you may create a table, a series of graphs, a single graph—choose something that appropriately displays the effects of lowering the temperature below 1, temperature at 1, and temperature above 1. Your demonstration must be *easily interpretable* and *accurate*.
# $$ \texttt{softmax}(z_i, \tau) = \frac{e^{\frac{z_i}{\tau}}}{\sum_{j = 1}^k e^{\frac{z_j}{\tau}}}$$
# 5. __6120 REQUIRED__ (python) create a demonstration of changing the top-k parameter, using the same vocabulary and probability distributions that you defined in the previous question.
#     1. To complete this task, you will need to write a function that actually samples the next word from your vocabulary (we'll only do one) and that takes a parameter to represent top k.
#     2. Top k defines the number of words we will consider from the vocabulary when choosing the next word (take the k most likely), then re-normalizes the distribution to only consider these words.
#     3. Demonstrate using your sampling function with different values for top-k, showing both the top-k sampled distribution and the next word that is ultimately chosen.

# %% [markdown]
# #### Helpful Note
# Definition of Temperature: "Temperature is a number used to tune the degree of randomness. A lower temperature means less randomness; a temperature of 0 will always yield the same output. " - https://docs.cohere.com/docs/temperature

# %%
# importing the necessary packages
import random
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def soft_max(z, temp=1):
    """
    param z: a list of z values which are a float number between -1 and 1 representing probabilities
    param temp: takes in an int; represents temperature; default = 0; lower number = less random 
    func: takes in a list of z values and normalizes them using the formula provided
    return: a list of outputs (the z values normalized)
    """
    denominator = 0
    e = math.e
    
    # calculate denominator 
    for j in range(len(z)): # from 0 - length of z list 
        # for each item in the list of z score
        x = e**(z[j] / temp)
        # raise e to its correlated z score divided by temp
        denominator += x
        # add x to the denmoniator 
    
    out = [] # create empty list to append output values too 
    
    for i in range(len(z)):
        # loop through each z score in the list 
        numerator = e**(z[i] / temp)
        # create our numerator 
        out.append(numerator / denominator)
        # append our numerator / denominator to our out list 
    
    return out

# %%
def sample(vocab, z, temp=1, top_k=-1):
    """
    param vocab: the list of vocabulary words
    param z: a list of z values which are a float number between -1 and 1 representing probabilities
    param temp: takes in an int; represents temperature; default = 0; lower number = less random 
    param top_k: the number of top words to consider during sampling
    func: takes in a list of z values and normalizes them using the formula provided
    return: returns a single word from the vocab list 
    """

    probabilities = soft_max(z, temp)
    # calls the soft_max function with z and temp; soft_max
    # calculates the probablities of z and returns a list of numbers

    if top_k != -1: # checks regular sampling or irregular
        output = np.random.choice(vocab, p=probabilities)
        # uses random to choose a random word & it's probability

    else:  # regular sampling 
        vocab_prob_tuples = [(word, prob) for word, prob in zip(vocab, probabilities)] 
        ## used LLM to help format how to create a tuple
        
        sorted_tuples = sorted(vocab_prob_tuples, key=lambda x: x[1], reverse=True)
        # creates a list of tuples, grouping each word to their probability & reverse sorts the list
        
        top_k_items = sorted_tuples[:top_k]
        # create a list of the top_k'th items in the list using slicing 
        
        
        probabilities_top_k = [0] * len(vocab) # create a list of 0's the size of the vocab list
        for word, prob in top_k_items:
            # for each word, prob in the top_k_items
            index = vocab.index(word)
            probabilities_top_k[index] = prob
            # find the index & set the index in the new list to the probability
            # zeroing out the non-top-k words
        
        output = np.random.choice(vocab, p=probabilities_top_k)
        # uses random to choose a random word from our top-k words
    
    return output

# %%
# create input sequence 
inp = ['The cat slept']

# define a vocabulary, k len of vocab 
vocab = ['I', 'hello', 'world', 'the', 'cat', 'slept', 'in', 'sun', 
         'run', 'to', 'store', 'get', 'groceries', 'make', 'dinner']

# define z 
z = [0.4, 0.2, 0.1, 0.9, 0.2, 0.2, 0.5, 0.3, 0.3, 0.8, 0.5, 0.6, 0.4, 0.5, 0.4]
z_prob = soft_max(z, 1)

# change these to tune the parameters
top_k = 4
temp = 1


result = sample(vocab, z_prob, temp, top_k)

# printing results
print('The vocabulary words are: ', vocab, '\n\n')

print('The temperature is: ', temp, '\n')
print('The top_k is: ', top_k, '\n\n')

print('The Top-', top_k, ' distribution are: ', sample(vocab, z_prob, temp, top_k), '\n')
print('The next word selected is: ', result)
# Out:
# The vocabulary words are:  ['I', 'hello', 'world', 'the', 'cat', 'slept', 'in', 'sun', 'run', 'to', 'store', 'get', 'groceries', 'make', 'dinner']
#
#
# The temperature is:  1
#
# The top_k is:  4
#
#
# The Top- 4  distribution are:  the
#
# The next word selected is:  the

# %%
# call soft_max 
temp_below_1 = soft_max(z, -2)
temp_1 = soft_max(z, 1)
temp_above_1 = soft_max(z, 2)

# plot the different outputs
plt.figure(figsize=(10, 6))
plt.plot(z, temp_below_1, label='Temperature -2')
plt.plot(z, temp_1, label='Temperature 1')
plt.plot(z, temp_above_1, label='Temperature 5')

# formatting
plt.title('Soft-max Output for Varying Temperatures')
plt.xlabel('Assigned z values')
plt.ylabel('Output')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Task 3: Large Language Models Philosophy & Considerations (15 points)
# ----
#
# 1. Make an argument for when a computer might be reasonably considered to "know" a word. Identify at least 3 components in your argument. Justify this choice. (4 - 6 sentences)
#
# Before making an arugment for or against a computer 'knowing' a word, I think it is best to define what 'knowing' a word means to me. As people, when we are learning a new language or learning our first language we can define 'knowing' a word as understanding the meaning of the word (definition), when to use the word in the given languages sentence structure and being able to recognizing the word. By this definition, I beleive that a computer might be considered to 'know' a word because of what I beleive are these three compenents (1. understanding the meaning 2. when to use it in a sentence and 3. recognizing the word). With large amounts of data, and computing power we are able to make a computer meet these requirements. However, when a computer knows a word or even knows several thousand words, we need to consider that it will lack the human understanding of the words, the connotation of the word. I beleive that computers have an opportunity to know what words are but lack an indepth understanding for how these words can be used.

# %% [markdown]
# 2. From your current understanding of LLMs and the definition that you just proposed, do LLMs "know" words? (2 - 4 sentences)
# As stated above, I beleive that computers have to opportunity to know what words are but may lack an indepth understanding for how these words can be used. With large language models, I beleive the same to be true. I think that with LLMs they understand how words have been used throughout the data they have been given, and they are able to gain a basic knowlegde on words from this data. LLMs have the ability to use words to create meaningful sentences, this is demonstrating a basic knowledge of words. I think that as LLMs grow and more data becomes avaliable the accuracy of these LLMs will imporve, making it so these LLM's know more words at a more indepth level.

# %% [markdown]
# 3. Given what you have learned about LLMs so far, what do you think the most important thing for people to understand about LLMs is? Justify your answer. (3 - 5 sentences)
# The most important thing for people to understand about LLMs is that it is trained off of already existing data (texts, writing, articles, blogs, etc.) Meaning that if the model was trained on data with any baises, it will most likely be reproduced through the LLMs outputs. Although these LLMs may 'know' words to the best of their ability, they do not have the same understanding of theses words as we do, they do not have the indepth context of these words. Another issue is that language is always changing, with definition and meanings of words changing - this makes it difficult to capture the languages we use through LLMs.

# %% [markdown]
# 5 points in this assignment are reserved for overall style (both for writing and for code submitted). All work submitted should be clear, easily interpretable, and checked for spelling, etc. (Re-read what you write and make sure it makes sense). Course staff are always happy to give grammatical help (but we won't pre-grade the content of your answers).
